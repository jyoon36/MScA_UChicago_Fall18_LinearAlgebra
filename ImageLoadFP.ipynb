# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import misc as smi
import numpy as np

# %%
my_image = smi.imread("C:/Users/Natasha/Desktop/misc/b.jpg")

# %%
#type(my_image)
my_image.shape
#my_image.dtype
# Out:
# (530, 530, 3)

# %%
#my_image = my_image

# %%
plt.imshow(my_image)#-100)

# %%
plt.imshow(my_image[:,:,1],cmap='gray')

# %%
my_image2 = smi.imread("C:/Users/Natasha/Desktop/misc/b.jpg")
my_image2.shape
abc = np.dot(my_image2[...,:3], [0.299, 0.587, 0.114])
abc.shape
# Out:
# (530, 530)

# %%
plt.imshow(abc,cmap='gray')

# %%
my_imagebw1 = smi.imread("C:/Users/Natasha/Desktop/misc/rosebw.jpeg")
my_imagebw1.shape
# Out:
# (2848, 4272, 3)

# %%
my_imagebw1[:,:,0]
# Out:
# array([[43, 42, 42, ..., 12, 12, 12],
#        [41, 41, 41, ..., 12, 12, 12],
#        [41, 42, 42, ..., 12, 12, 11],
#        ...,
#        [32, 31, 31, ..., 27, 28, 28],
#        [31, 31, 31, ..., 27, 28, 28],
#        [31, 32, 31, ..., 28, 29, 29]], dtype=uint8)

# %%
plt.imshow(my_imagebw1[:,:,2],cmap="gray")

# %%
my_imagebw1_rs = smi.imresize(my_imagebw1, (512, 860))

# %%
plt.imshow(my_imagebw1_rs)

# %%
my_imagebw1_rs.shape
# Out:
# (512L, 860L, 3L)

# %%
flat1=my_image2.ravel()

# %%
vector1 = np.matrix(flat1)
vector1
# Out:
# matrix([[134, 104,  66, ...,  53,  41,  41]], dtype=uint8)

# %%
type(vector1)
# Out:
# numpy.matrixlib.defmatrix.matrix

# %%
vector1.shape
# Out:
# (1, 842700)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-4e7055abb9d2> in <module>()
# ----> 1 vect2 = np.matrix.flat(my_image2)
#       2 vect2
#
# TypeError: 'getset_descriptor' object is not callable
